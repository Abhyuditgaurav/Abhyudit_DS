# %% [markdown]
# Method - Function associated with a class
# 1. Class is a blueprint to creating an instance of a class.
# 2. Instance variable contains data that is unique to that instance.
# 3. __init__ : means initialize. This method run automatically when we call a class.
# 4. When we create methods inside a class they receive instance as first argument automatically.By convention we should call instance as self.

# %%
class Employee:
    
    def __init__(self,first,last,pay):
        self.first=first
        self.last=last
        self.pay=pay
        self.email=first+'.'+last+'@company.com'

    def fullname(self):
        return '{} {}'.format(self.first,self.last)

emp1=Employee('Corey','Schafer',500000)

print(emp1.email)
print(Employee.fullname(emp1)) # Another way of calling a class method.
print(emp1.fullname())
print(emp1.__dict__) # Method to get name space of any instance.
# Out:
# Corey.Schafer@company.com
# Corey Schafer
# Corey Schafer
# {'first': 'Corey', 'last': 'Schafer', 'pay': 500000, 'email': 'Corey.Schafer@company.com'}

# %% [markdown]
# 1. class variables are variables that are shared among all instances of a class.
# 2. class variables can be accessed using both class and instance. When we try to access an attribute on an instance it will first check if that instance contains that attribute and if it doesn't then it will check the class or any class that it inherits contains that attribute.

# %%
class Employee:
    
    raise_amount=1.04 # class variable
    num_of_emps=0 # class variable

    def __init__(self,first,last,pay):
        self.first=first
        self.last=last
        self.pay=pay
        self.email=first+'.'+last+'@company.com'

        Employee.num_of_emps += 1 # calling this class variable using class as we want this to be same for every instance.

    def fullname(self):
        return '{} {}'.format(self.first,self.last)
    
    def apply_raise(self):
        self.pay=int(self.pay*self.raise_amount) # calling the class variable using instance.


print("No of emplyees:",Employee.num_of_emps)

emp1=Employee('Corey','Schafer',500000)
emp2=Employee('Abhyudit','Shandilya',700000)

print(emp1.raise_amount)
print(emp1.__dict__)
print(Employee.raise_amount)
print(Employee.__dict__)

emp1.raise_amount=1.05 # If we are calling a class variable using instance we can assign different values to different instances
print(emp1.raise_amount)
print(emp1.__dict__)

print(emp2.raise_amount)
print(emp2.__dict__)

print("No of emplyees:",Employee.num_of_emps)
# Out:
# No of emplyees: 0
# 1.04
# {'first': 'Corey', 'last': 'Schafer', 'pay': 500000, 'email': 'Corey.Schafer@company.com'}
# 1.04
# {'__module__': '__main__', 'raise_amount': 1.04, 'num_of_emps': 2, '__init__': <function Employee.__init__ at 0x102d6b700>, 'fullname': <function Employee.fullname at 0x102d6b160>, 'apply_raise': <function Employee.apply_raise at 0x102d46820>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}
# 1.05
# {'first': 'Corey', 'last': 'Schafer', 'pay': 500000, 'email': 'Corey.Schafer@company.com', 'raise_amount': 1.05}
# 1.04
# {'first': 'Abhyudit', 'last': 'Shandilya', 'pay': 700000, 'email': 'Abhyudit.Shandilya@company.com'}
# No of emplyees: 2
